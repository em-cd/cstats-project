# %% [markdown]
# # House Prices Project
#
# **Dataset**: [House Prices - Advanced Regression Techniques](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)
#
# **Goal**: Predict the sale price of houses using statistical and machine learning methods.

# %% [markdown]
# ---
# ## Setup and Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from itertools import combinations
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
import statsmodels.stats.api as sms
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import Ridge, Lasso
from statsmodels.stats.anova import anova_lm
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

pd.set_option('display.max_columns', 100)
# %matplotlib inline

# %% [markdown]
# ---
# ## Load Data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

print(f'Training set: {train.shape[0]} rows, {train.shape[1]} columns')
print(f'Test set: {test.shape[0]} rows, {test.shape[1]} columns')

train.head()
test.head()
# Out:
# Training set: 1460 rows, 81 columns
# Test set: 1459 rows, 80 columns
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
# ...

# %%
# Set a pink-themed style
pink_main = '#FF69B4'
pink_dark = '#FF1493'
pink_light = '#FFB6C1'
pink_pale = '#FFC0CB'
pink_accent = "#6D000F"

# %%
# Explore the target variable
print(train['SalePrice'].describe())

fig, axes = plt.subplots(1, 1, figsize=(12, 4))
axes.hist(train['SalePrice'], bins=50, edgecolor=pink_dark, color=pink_light)
axes.set_title('SalePrice Distribution')
axes.set_xlabel('SalePrice')
plt.tight_layout()
plt.show()

print(f'Skewness: {train["SalePrice"].skew():.3f}')
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Skewness: 1.883

# %% [markdown]
# The data is heavily skewed, what kind of transformation can we apply to make it more normal?

# %%
# Apply a log transformation so y' = log(price + 1) (+1 for safety/robustness)
# Then we can interpret coefficients as percentage changes instead of absolute price changes

df = train.copy()
df["LogSalePrice"] = np.log1p(df["SalePrice"])

print(df['LogSalePrice'].describe())

fig, axes = plt.subplots(1, 1, figsize=(12, 4))
axes.hist(df['LogSalePrice'], bins=50, edgecolor=pink_dark, color=pink_light)
axes.set_title('LogSalePrice Distribution')
axes.set_xlabel('LogSalePrice')
plt.tight_layout()
plt.show()

print(f'Skewness: {df["LogSalePrice"].skew():.3f}')
# Out:
# count    1460.000000
# mean       12.024057
# std         0.399449
# min        10.460271
# 25%        11.775105
# 50%        12.001512
# 75%        12.273736
# max        13.534474
# Name: LogSalePrice, dtype: float64
# Skewness: 0.121

# %%
# Explore missing values
(df.isna().sum()[df.isna().sum() > 0] / len(df)).sort_values(ascending=False) * 100
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# MasVnrType      59.726027
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# BsmtQual         2.534247
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64

# %%
# Let's clean up!
# Wrapped the cleaning process into a function so it can be reused later
def clean_data(df):
    # Assume no data about pool -> no pool, and same for misc, alley and fence
    df["PoolQC"] = df["PoolQC"].fillna("NA")
    df["MiscFeature"] = df["MiscFeature"].fillna("NA")
    df["Alley"] = df["Alley"].fillna("NA")
    df["Fence"] = df["Fence"].fillna("NA")

    # Assume no data about masonry area -> area = 0
    df["MasVnrArea"] = df["MasVnrArea"].fillna(0)
    # If masonry area is 0, veneer type should be none
    df.loc[(df["MasVnrArea"] == 0) & (df["MasVnrType"].isna()), "MasVnrType"] = "None"
    # For any with masonry area > 0 but veneer type NaN (4 rows) -> fill with most common veneer type
    df["MasVnrType"] = df["MasVnrType"].fillna(df.loc[df["MasVnrArea"] > 0, "MasVnrType"].mode()[0])

    # No fireplaces -> fireplace quality is NA
    df.loc[(df["Fireplaces"] == 0) & (df["FireplaceQu"].isna()), "FireplaceQu"] = "NA"

    # Same treatment for garage
    df.loc[(df["GarageArea"] == 0) & (df["GarageFinish"].isna()), "GarageFinish"] = "NA"
    df.loc[(df["GarageArea"] == 0) & (df["GarageQual"].isna()), "GarageQual"] = "NA"
    df.loc[(df["GarageArea"] == 0) & (df["GarageType"].isna()), "GarageType"] = "NA"
    df.loc[(df["GarageArea"] == 0) & (df["GarageCond"].isna()), "GarageCond"] = "NA"
    # Add a separate column for garage/no garage 
    df["HasGarage"] = df["GarageYrBlt"].notna().astype(int)
    # Set year built to 0 if no garage
    df["GarageYrBlt"] = df["GarageYrBlt"].fillna(0)

    # Again for basement: no basement square feet -> no basement
    df.loc[(df["TotalBsmtSF"] == 0), ["BsmtFinType1", "BsmtFinType2", "BsmtExposure", "BsmtQual", "BsmtCond"]] = "NA"
    # Deal with any leftover missing values
    df[["BsmtFinType2", "BsmtExposure"]] = df[["BsmtFinType2", "BsmtExposure"]].fillna("NA")

    # Set missing lot frontage to the neighbourhood median
    df["LotFrontage"] = df["LotFrontage"].fillna(
        df.groupby("Neighborhood")["LotFrontage"].transform("median")
    )

    # Fill in electrical with most frequent value
    df["Electrical"] = df["Electrical"].fillna(df["Electrical"].mode()[0])

    # Just because 'NA' is confusing, let's rename it to 'None'
    df = df.replace("NA", "None")

    return df

df = clean_data(df)

# Check everything is clean
print((df.isna().sum()[df.isna().sum() > 0] / len(df)).sort_values(ascending=False) * 100)

display(df)
# Out:
# Series([], dtype: float64)
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None      Reg
# 1        2          20       RL         80.0     9600   Pave  None      Reg
# 2        3          60       RL         68.0    11250   Pave  None      IR1
# 3        4          70       RL         60.0     9550   Pave  None      IR1
# 4        5          60       RL         84.0    14260   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
# ...

# %% [markdown]
# ---
# ## Part 1: Classical Statistical Inference
#
# Apply basic statistical methods to explore the data:
# - **Sample mean and variance** of `SalePrice` and key features
# - **Confidence intervals** for the mean SalePrice
# - **Hypothesis testing** — e.g. is the mean SalePrice significantly different from \$180,000? Is the distribution of the transformed `SalePrice` normal (Shapiro-Wilk)?
# - Visualize distributions and support your conclusions with plots

# %% [markdown]
# #### 1.1 Sample mean and variance of `SalePrice` and key features

# %%
# --- 1.1 Sample Mean and Variance of SalePrice ---
print("=" * 60)
print("1.1 Sample Mean and Variance")
print("=" * 60)

sale_price = df["SalePrice"]
sale_price_log = df["LogSalePrice"]

n = len(sale_price)
mean_price = sale_price.mean()
var_price = sale_price.var(ddof=1)
std_price = sale_price.std(ddof=1)

mean_log = sale_price_log.mean()
var_log = sale_price_log.var(ddof=1)
std_log = sale_price_log.std(ddof=1)

print(f"SalePrice:    n={n}, mean=${mean_price:,.2f}, var={var_price:,.2f}, std=${std_price:,.2f}")
print(f"LogSalePrice: n={n}, mean={mean_log:.4f}, var={var_log:.4f}, std={std_log:.4f}")

key_features = ["GrLivArea", "TotalBsmtSF", "LotArea", "GarageArea", "YearBuilt"]
summary_stats = df[key_features].agg(["mean", "var", "std", "median", "min", "max"]).T
summary_stats.columns = ["Mean", "Variance", "Std Dev", "Median", "Min", "Max"]
print("\nKey Numerical Features - Summary Statistics:")
print(summary_stats.round(2))
# Out:
# ...
# 1.1 Sample Mean and Variance
# ...
# SalePrice:    n=1460, mean=$180,921.20, var=6,311,111,264.30, std=$79,442.50
# LogSalePrice: n=1460, mean=12.0241, var=0.1596, std=0.3994
#
# Key Numerical Features - Summary Statistics:
#                  Mean     Variance  Std Dev  Median     Min       Max
# GrLivArea     1515.46    276129.63   525.48  1464.0   334.0    5642.0
# TotalBsmtSF   1057.43    192462.36   438.71   991.5     0.0    6110.0
# LotArea      10516.83  99625649.65  9981.26  9478.5  1300.0  215245.0
# GarageArea     472.98     45712.51   213.80   480.0     0.0    1418.0
# YearBuilt     1971.27       912.22    30.20  1973.0  1872.0    2010.0

# %%
# --- Visualization: distributions of SalePrice and log-transformed ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(sale_price, bins=50, edgecolor=pink_dark, color=pink_light, density=True)
axes[0].axvline(mean_price, color=pink_dark, linestyle='--', linewidth=2, label=f'Mean = ${mean_price:,.0f}')
axes[0].axvline(sale_price.median(), color=pink_accent, linestyle='--', linewidth=2, label=f'Median = ${sale_price.median():,.0f}')
axes[0].set_title('SalePrice Distribution', fontweight='bold')
axes[0].set_xlabel('SalePrice ($)')
axes[0].set_ylabel('Density')
axes[0].legend()

axes[1].hist(sale_price_log, bins=50, edgecolor=pink_dark, color=pink_light, density=True)
x_norm = np.linspace(sale_price_log.min(), sale_price_log.max(), 200)
axes[1].plot(x_norm, stats.norm.pdf(x_norm, mean_log, std_log), color=pink_dark, lw=2, label='Normal fit')
axes[1].axvline(mean_log, color=pink_accent, linestyle='--', linewidth=2, label=f'Mean = {mean_log:.3f}')
axes[1].set_title('Log(SalePrice+1) Distribution', fontweight='bold')
axes[1].set_xlabel('log(SalePrice + 1)')
axes[1].set_ylabel('Density')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# --- Visualization: key features distributions ---
fig, axes = plt.subplots(1, len(key_features), figsize=(4 * len(key_features), 4))
for i, feat in enumerate(key_features):
    axes[i].hist(df[feat], bins=40, edgecolor=pink_dark, color=pink_light)
    axes[i].axvline(df[feat].mean(), color=pink_accent, linestyle='--', linewidth=1.5)
    axes[i].set_title(feat, fontweight='bold')
    axes[i].set_xlabel(feat)
plt.suptitle("Distributions of Key Numerical Features (dashed = mean)", y=1.02, fontweight='bold', color=pink_dark)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.2 Confidence intervals for the mean `SalePrice`

# %%
print("=" * 60)
print("1.2 Confidence Intervals")
print("=" * 60)

alpha = 0.05

se_price = std_price / np.sqrt(n)
t_crit = stats.t.ppf(1 - alpha / 2, df=n - 1)
ci_price = (mean_price - t_crit * se_price, mean_price + t_crit * se_price)
print(f"\n95% CI for mean SalePrice (t-interval):")
print(f"  ({ci_price[0]:,.2f}, {ci_price[1]:,.2f})")

se_log = std_log / np.sqrt(n)
ci_log = (mean_log - t_crit * se_log, mean_log + t_crit * se_log)
print(f"\n95% CI for mean log(SalePrice+1) (t-interval):")
print(f"  ({ci_log[0]:.4f}, {ci_log[1]:.4f})")

ci_log_dollar = (np.expm1(ci_log[0]), np.expm1(ci_log[1]))
print(f"  Back-transformed to dollars: (${ci_log_dollar[0]:,.2f}, ${ci_log_dollar[1]:,.2f})")

chi2_lower = stats.chi2.ppf(alpha / 2, df=n - 1)
chi2_upper = stats.chi2.ppf(1 - alpha / 2, df=n - 1)
ci_var = ((n - 1) * var_price / chi2_upper, (n - 1) * var_price / chi2_lower)
print(f"\n95% CI for SalePrice variance (chi-squared):")
print(f"  ({ci_var[0]:,.2f}, {ci_var[1]:,.2f})")

ci_var_log = ((n - 1) * var_log / chi2_upper, (n - 1) * var_log / chi2_lower)
print(f"\n95% CI for log(SalePrice+1) variance (chi-squared):")
print(f"  ({ci_var_log[0]:,.2f}, {ci_var_log[1]:,.2f})")

print(f"\n95% Confidence Intervals for Key Feature Means:")
ci_table = []
for feat in key_features:
    feat_mean = df[feat].mean()
    feat_se = df[feat].std(ddof=1) / np.sqrt(n)
    ci_lo = feat_mean - t_crit * feat_se
    ci_hi = feat_mean + t_crit * feat_se
    ci_table.append({"Feature": feat, "Mean": feat_mean, "CI Lower": ci_lo, "CI Upper": ci_hi})
ci_df = pd.DataFrame(ci_table).set_index("Feature")
print(ci_df.round(2))
# Out:
# ...
# 1.2 Confidence Intervals
# ...
#
# 95% CI for mean SalePrice (t-interval):
#   (176,842.84, 184,999.55)
#
# 95% CI for mean log(SalePrice+1) (t-interval):
#   (12.0036, 12.0446)
#   Back-transformed to dollars: ($163,332.73, $170,170.83)
#
# 95% CI for SalePrice variance (chi-squared):
#   (5,877,056,095.66, 6,795,343,509.17)
#
# 95% CI for log(SalePrice+1) variance (chi-squared):
#   (0.15, 0.17)
#
# 95% Confidence Intervals for Key Feature Means:
#                  Mean  CI Lower  CI Upper
# Feature
# GrLivArea     1515.46   1488.49   1542.44
# TotalBsmtSF   1057.43   1034.91   1079.95
# LotArea      10516.83  10004.42  11029.24
# GarageArea     472.98    462.00    483.96
# YearBuilt     1971.27   1969.72   1972.82

# %%
# --- Visualization: CI for Mean SalePrice ---
fig, ax = plt.subplots(figsize=(8, 3))
ax.errorbar(mean_price, 0, xerr=t_crit * se_price, fmt='o', color=pink_dark,
            capsize=10, markersize=8, linewidth=2, markerfacecolor=pink_light,
            markeredgecolor=pink_dark, ecolor=pink_main)
ax.axvline(163000, color=pink_accent, linestyle='--', linewidth=2, label='$163,000 (median = H₀)')
ax.set_yticks([])
ax.set_xlabel('SalePrice ($)')
ax.set_title('95% Confidence Interval for Mean SalePrice', fontweight='bold', color=pink_dark)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.3 Hypothesis testing

# %%
# --- Test 1: Is mean SalePrice significantly greater than the median SalePrice? ---
# The raw SalePrice distribution is right-skewed (skewness = 1.88).
# In a right-skewed distribution we expect mean > median.
# We test this formally: H₀: μ = $163,000 (the sample median) vs H₁: μ > $163,000 (one-sided).
# Rejecting H₀ statistically confirms the right-skew we observe visually.
mu_0 = 163000
t_stat = (mean_price - mu_0) / se_price
p_value_ttest = stats.t.sf(abs(t_stat), df=n - 1)  # one-sided

print(f"\nTest 1: H₀: μ = ${mu_0:,} vs H₁: μ > ${mu_0:,}")
print(f"  (Testing whether the mean is significantly above the median — evidence of right skew)")
print(f"  Sample mean:   ${mean_price:,.2f}")
print(f"  Sample median: ${mu_0:,}")
print(f"  t-statistic: {t_stat:.4f}")
print(f"  p-value (one-sided): {p_value_ttest:.6f}")
print(f"  Decision at α=0.05: {'Reject H₀' if p_value_ttest < alpha else 'Fail to reject H₀'}")

t_stat_scipy, p_val_two = stats.ttest_1samp(sale_price, mu_0)
p_val_one = p_val_two / 2  # convert to one-sided
print(f"  (scipy verification: t={t_stat_scipy:.4f}, p={p_val_one:.6f})")
# Out:
# Test 1: H₀: μ = $163,000 vs H₁: μ > $163,000
#   (Testing whether the mean is significantly above the median — evidence of right skew)
#   Sample mean:   $180,921.20
#   Sample median: $163,000
#   t-statistic: 8.6197
#   p-value (one-sided): 0.000000
#   Decision at α=0.05: Reject H₀
#   (scipy verification: t=8.6197, p=0.000000)

# %%
# --- Test 2: Shapiro-Wilk normality tests ---
if n > 5000:
    sample_sw = sale_price.sample(5000, random_state=42)
else:
    sample_sw = sale_price
sw_stat, sw_p = stats.shapiro(sample_sw)
print(f"Test 2a: Shapiro-Wilk normality test on SalePrice")
print(f"  W-statistic: {sw_stat:.6f}")
print(f"  p-value: {sw_p:.6e}")
print(f"  Decision at α=0.05: {'Reject H₀ (NOT normal)' if sw_p < alpha else 'Fail to reject H₀ (normal)'}")

if n > 5000:
    sample_sw_log = sale_price_log.sample(5000, random_state=42)
else:
    sample_sw_log = sale_price_log
sw_stat_log, sw_p_log = stats.shapiro(sample_sw_log)
print(f"\nTest 2b: Shapiro-Wilk normality test on log(SalePrice+1)")
print(f"  W-statistic: {sw_stat_log:.6f}")
print(f"  p-value: {sw_p_log:.6e}")
print(f"  Decision at α=0.05: {'Reject H₀ (NOT normal)' if sw_p_log < alpha else 'Fail to reject H₀ (normal)'}")
# Out:
# Test 2a: Shapiro-Wilk normality test on SalePrice
#   W-statistic: 0.869671
#   p-value: 3.206141e-33
#   Decision at α=0.05: Reject H₀ (NOT normal)
#
# Test 2b: Shapiro-Wilk normality test on log(SalePrice+1)
#   W-statistic: 0.991207
#   p-value: 1.149074e-07
#   Decision at α=0.05: Reject H₀ (NOT normal)

# %%
# --- Test 3: Two-sample t-test: Central Air ---
group_yes = df.loc[df["CentralAir"] == "Y", "SalePrice"]
group_no = df.loc[df["CentralAir"] == "N", "SalePrice"]
t_air, p_air = stats.ttest_ind(group_yes, group_no, equal_var=False)
print(f"Test 3: Welch's t-test — CentralAir=Y vs CentralAir=N on SalePrice")
print(f"  Mean (Yes): ${group_yes.mean():,.2f} (n={len(group_yes)})")
print(f"  Mean (No):  ${group_no.mean():,.2f} (n={len(group_no)})")
print(f"  t-statistic: {t_air:.4f}")
print(f"  p-value: {p_air:.6e}")
print(f"  Decision at α=0.05: {'Reject H₀ (significant difference)' if p_air < alpha else 'Fail to reject H₀'}")
# Out:
# Test 3: Welch's t-test — CentralAir=Y vs CentralAir=N on SalePrice
#   Mean (Yes): $186,186.71 (n=1365)
#   Mean (No):  $105,264.07 (n=95)
#   t-statistic: 17.2678
#   p-value: 2.280814e-37
#   Decision at α=0.05: Reject H₀ (significant difference)

# %%
# --- Visualization: QQ plots ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

stats.probplot(sale_price, dist="norm", plot=axes[0])
axes[0].set_title("Q-Q Plot: SalePrice", fontweight='bold', color=pink_dark)
axes[0].get_lines()[0].set_markerfacecolor(pink_light)
axes[0].get_lines()[0].set_markeredgecolor(pink_dark)
axes[0].get_lines()[0].set_markersize(3)
axes[0].get_lines()[1].set_color(pink_dark)

stats.probplot(sale_price_log, dist="norm", plot=axes[1])
axes[1].set_title("Q-Q Plot: log(SalePrice+1)", fontweight='bold', color=pink_dark)
axes[1].get_lines()[0].set_markerfacecolor(pink_light)
axes[1].get_lines()[0].set_markeredgecolor(pink_dark)
axes[1].get_lines()[0].set_markersize(3)
axes[1].get_lines()[1].set_color(pink_dark)

plt.tight_layout()
plt.show()

# %%
# --- Visualization: Central Air boxplot ---
fig, ax = plt.subplots(figsize=(6, 5))
bp = df.boxplot(column='SalePrice', by='CentralAir', ax=ax,
                patch_artist=True, return_type='dict')
for patch in bp['SalePrice']['boxes']:
    patch.set_facecolor(pink_light)
    patch.set_edgecolor(pink_dark)
for whisker in bp['SalePrice']['whiskers']:
    whisker.set_color(pink_dark)
for cap in bp['SalePrice']['caps']:
    cap.set_color(pink_dark)
for median in bp['SalePrice']['medians']:
    median.set_color(pink_dark)
    median.set_linewidth(2)
for flier in bp['SalePrice']['fliers']:
    flier.set_markerfacecolor(pink_light)
    flier.set_markeredgecolor(pink_accent)
ax.set_title('SalePrice by Central Air Conditioning', fontweight='bold', color=pink_dark)
ax.set_xlabel('Central Air')
ax.set_ylabel('SalePrice ($)')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1.4 Summary of findings from statistical tests

# %%
# --- 1.4 Summary Table ---
print("=" * 60)
print("1.4 Summary of Statistical Tests")
print("=" * 60)

summary_tests = pd.DataFrame({
    "Test": [
        "One-sample t-test (μ = $163,000, one-sided)",
        "Shapiro-Wilk (SalePrice)",
        "Shapiro-Wilk (log SalePrice)",
        "Welch t-test (CentralAir)"
    ],
    "Statistic": [t_stat, sw_stat, sw_stat_log, t_air],
    "p-value": [p_value_ttest, sw_p, sw_p_log, p_air],
    "Reject H₀ (α=0.05)": [
        p_value_ttest < alpha, sw_p < alpha, sw_p_log < alpha,
        p_air < alpha
    ]
})
print(summary_tests.to_string(index=False))
# Out:
# ...
# 1.4 Summary of Statistical Tests
# ...
#                                        Test  Statistic      p-value  Reject H₀ (α=0.05)
# One-sample t-test (μ = $163,000, one-sided)   0.443073 6.577785e-01               False
#                    Shapiro-Wilk (SalePrice)   0.869671 3.206141e-33                True
#                Shapiro-Wilk (log SalePrice)   0.991207 1.149074e-07                True
#                   Welch t-test (CentralAir)  17.267773 2.280814e-37                True

# %% [markdown]
# ---
# ## Part 2: ANOVA — Finding Significant Features
#
# Use ANOVA to determine which of the following **10 features** have a statistically significant effect on the transformed SalePrice.
#
# **Given features (10):**
#
# | # | Feature | Levels | Description |
# |---|---|---|---|
# | 1 | `OverallQual` | 1–10 | Overall material and finish quality |
# | 2 | `ExterQual` | Po, Fa, TA, Gd, Ex | Exterior material quality |
# | 3 | `BsmtQual` | None, Po, Fa, TA, Gd, Ex | Basement height quality |
# | 4 | `KitchenQual` | Po, Fa, TA, Gd, Ex | Kitchen quality |
# | 5 | `FireplaceQu` | None, Po, Fa, TA, Gd, Ex | Fireplace quality |
# | 6 | `CentralAir` | N, Y | Central air conditioning |
# | 7 | `LotShape` | IR3, IR2, IR1, Reg | General shape of property |
# | 8 | `LandSlope` | Sev, Mod, Gtl | Slope of property |
# | 9 | `MoSold` | 1–12 | Month sold |
# | 10 | `YrSold` | 2006–2010 | Year sold |
#
# **Tasks:**
# 1. Extract these features into a dataframe and run **one-way ANOVA** on each
# 2. Identify which features are significant (p < 0.05)
# 3. Run a **two-way ANOVA** to test for interaction effects between pairs of significant features
# 4. Use **Tukey HSD** post-hoc tests where appropriate
# 5. Summarize: which features and interactions are significant?

# %% [markdown]
# #### 2.1 Extract features and run one-way ANOVA on each

# %%
features_for_anova = ["OverallQual", "ExterQual", "BsmtQual", "KitchenQual", "FireplaceQu", "CentralAir", "LotShape", "LandSlope", "MoSold", "YrSold"]

df_for_anova = df[features_for_anova + ["LogSalePrice"]].copy()
df_for_anova.head()
# Out:
#    OverallQual ExterQual BsmtQual KitchenQual FireplaceQu CentralAir LotShape  \
# 0            7        Gd       Gd          Gd        None          Y      Reg
# 1            6        TA       Gd          TA          TA          Y      Reg
# 2            7        Gd       Gd          Gd          TA          Y      IR1
# 3            7        TA       TA          Gd          Gd          Y      IR1
# 4            8        Gd       Gd          Gd          TA          Y      IR1
#
#   LandSlope  MoSold  YrSold  LogSalePrice
# 0       Gtl       2    2008     12.247699
# 1       Gtl       5    2007     12.109016
# 2       Gtl       9    2008     12.317171
# 3       Gtl       2    2006     11.849405
# 4       Gtl      12    2008     12.429220

# %%
anova1_results = []

for feature in features_for_anova:
  groups = [group["LogSalePrice"].values for name, group in df_for_anova.groupby(feature)]
  f_stat, p_value = stats.f_oneway(*groups)

  anova1_results.append({
      "feature": feature,
      "f_statistic": f_stat,
      "p_value": p_value,
      "num_groups": len(groups)
  })

anova1_df = pd.DataFrame(anova1_results)
anova1_df = anova1_df.sort_values("p_value")
anova1_df["significant"] = anova1_df["p_value"] < 0.05
anova1_df
# Out:
#        feature  f_statistic        p_value  num_groups  significant
# 0  OverallQual   332.166960   0.000000e+00          10         True
# 1    ExterQual   415.304259  6.930372e-195           4         True
# 2     BsmtQual   300.392915  2.029970e-188           5         True
# 3  KitchenQual   393.320922  4.438817e-187           4         True
# 4  FireplaceQu   131.198588  6.961918e-115           6         True
# 5   CentralAir   205.666008   9.859878e-44           2         True
# 6     LotShape    46.728785   7.856720e-29           4         True
# 7    LandSlope     1.083050   3.388339e-01           3        False
# 8       MoSold     0.993741   4.496614e-01          12        False
# 9       YrSold     0.738615   5.656386e-01           5        False

# %% [markdown]
# #### 2.2 Show which features are significant according to one-way ANOVA

# %%
significant_features = anova1_df[anova1_df["significant"]]["feature"].tolist()
print(f"Significant features: {significant_features}")

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Overall Quality
sns.boxplot(
    data=df_for_anova,
    x="OverallQual",
    y="LogSalePrice",
    color=pink_light,
    linecolor=pink_dark,
    ax=axes[0]
)

axes[0].set_title("Log Sale Price by Overall Quality")
axes[0].set_xlabel("Overall Quality (1–10)")
axes[0].set_ylabel("Log(Sale Price)")

# Plot 2: Exterior Quality
quality_order = ["None", "Po", "Fa", "TA", "Gd", "Ex"]

existing_order = [
    q for q in quality_order
    if q in df_for_anova["ExterQual"].dropna().unique()
]

sns.boxplot(
    data=df_for_anova,
    x="ExterQual",
    y="LogSalePrice",
    color=pink_light,
    linecolor=pink_dark,
    ax=axes[1],
    order=existing_order
)

axes[1].set_title("Log Sale Price by Exterior Quality")
axes[1].set_xlabel("Exterior Quality")
axes[1].set_ylabel("Log(Sale Price)")

plt.tight_layout()
plt.show()


fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Plot 3: Lot Shape
sns.boxplot(
    data=df_for_anova,
    x="LotShape",
    y="LogSalePrice",
    color=pink_light,
    linecolor=pink_dark,
    ax=axes[0]
)

axes[0].set_title("Log Sale Price by LotShape")
axes[0].set_xlabel("LotShape")
axes[0].set_ylabel("Log(Sale Price)")

# Plot 4: Basement Quality
existing_order = [
    q for q in quality_order
    if q in df_for_anova["BsmtQual"].dropna().unique()
]

sns.boxplot(
    data=df_for_anova,
    x="BsmtQual",
    y="LogSalePrice",
    color=pink_light,
    linecolor=pink_dark,
    ax=axes[1],
    order=existing_order
)

axes[1].set_title("Log Sale Price by Basement Quality")
axes[1].set_xlabel("Basement Quality")
axes[1].set_ylabel("Log(Sale Price)")

plt.tight_layout()
plt.show()
# Out:
# Significant features: ['OverallQual', 'ExterQual', 'BsmtQual', 'KitchenQual', 'FireplaceQu', 'CentralAir', 'LotShape']

# %% [markdown]
# #### 2.3 Run 2-way ANOVA on pairs of significant features

# %%
anova2_results = []

for f1, f2 in combinations(significant_features, 2):
    formula = f"LogSalePrice ~ C({f1}) * C({f2})"
    model = smf.ols(formula, data=df_for_anova).fit()
    anova = sm.stats.anova_lm(model, typ=2)

    anova2_results.append({
        "feature1": f1,
        "feature2": f2,
        "p_interaction": anova.loc[f"C({f1}):C({f2})", "PR(>F)"]
    })

anova2_df = pd.DataFrame(anova2_results).sort_values("p_interaction")
anova2_df["significant"] = anova2_df["p_interaction"] < 0.05
anova2_df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 27, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# ...

# %%
# Check frequency of some of the combinations using contingency table
print(pd.crosstab(df_for_anova["OverallQual"], df_for_anova["KitchenQual"]))
print(pd.crosstab(df_for_anova["FireplaceQu"], df_for_anova["LotShape"]))
# Out:
# KitchenQual  Ex  Fa   Gd   TA
# OverallQual
# 1             0   2    0    0
# 2             0   2    0    1
# 3             0   3    1   16
# 4             0  12   10   94
# 5             8   9   60  320
# 6             2  10  127  235
# 7            10   1  244   64
# 8            30   0  133    5
# 9            35   0    8    0
# 10           15   0    3    0
# LotShape     IR1  IR2  IR3  Reg
# FireplaceQu
# Ex            11    2    0   11
# Fa            12    1    1   19
# Gd           147   11    5  217
# None         163   15    1  511
# Po             6    0    0   14
# TA           145   12    3  153

# %%
# Visualise interactions with a heatmap
qual_feat = "ExterQual"

# Create pivot table of means
heatmap_data = pd.pivot_table(
    df_for_anova,
    values="LogSalePrice",
    index="OverallQual",
    columns=qual_feat,
    aggfunc="mean"
)

# Order the quality categories
quality_order = ["None", "Po", "Fa", "TA", "Gd", "Ex"]
existing_order = [
    q for q in quality_order
    if q in heatmap_data.columns
]
heatmap_data = heatmap_data.reindex(columns=existing_order)

plt.figure(figsize=(8, 6))

sns.heatmap(
    heatmap_data,
    cmap="flare",
    annot=True,
    fmt=".2f"
)

plt.title(f"Mean Log Sale Price: OverallQual × {qual_feat}")
plt.xlabel(qual_feat)
plt.ylabel("Overall Quality")
plt.show()

# %% [markdown]
# #### 2.4 Run Tukey's HSD on significant features from one-way ANOVA

# %%
for feature in significant_features:
    print("\n" + "="*50)
    print(f"Tukey HSD for {feature}")
    print("="*50)

    tukey = pairwise_tukeyhsd(
        endog=df_for_anova["LogSalePrice"],
        groups=df_for_anova[feature],
        alpha=0.05
    )

    print(tukey)
# Out:
# ...
# Tukey HSD for OverallQual
# ...
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      1      2   0.0266    1.0 -0.6358  0.689  False
#      1      3   0.5387 0.0495  0.0005 1.0768   True
#      1      4   0.7583 0.0002  0.2409 1.2758   True
#      1      5   0.9818    0.0  0.4675 1.4962   True
#      1      6   1.1685    0.0   0.654 1.6829   True
#      1      7    1.423    0.0  0.9083 1.9376   True
#      1      8   1.6984    0.0  1.1822 2.2145   True
#      1      9   1.9944    0.0  1.4696 2.5193   True
#      1     10   2.1225    0.0  1.5817 2.6633   True
#      2      3   0.5121 0.0117  0.0628 0.9613   True
#      2      4   0.7318    0.0  0.3074 1.1561   True
#      2      5   0.9553    0.0  0.5348 1.3758   True
#      2      6   1.1419    0.0  0.7213 1.5625   True
#      2      7   1.3964    0.0  0.9755 1.8173   True
#      2      8   1.6718    0.0  1.2491 2.0944   True
# ...

# %% [markdown]
# #### 2.5 Summary of ANOVA analysis
#
# One-way ANOVA shows that most quality-related features (e.g., OverallQual, ExterQual, KitchenQual, BsmtQual, FireplaceQu) and CentralAir significantly affect LogSalePrice, with higher quality levels consistently linked to higher prices. In contrast, LandSlope, MoSold, and YrSold are not significant.
#
# Tukey tests confirm strong ordinal trends for quality variables, while LotShape has mixed effects.
#
# Two-way ANOVA reveals many significant interactions, but the design is unbalanced and many interactions likely reflect correlations among quality features rather than true independent effects. These should be interpreted as associations, not causal relationships.

# %% [markdown]
# ---
# ## Part 3: 2^k Factorial Design
#
# Pick k binary (or binarized) factors from the significant features found in Part 2 and apply a factorial design analysis. For example you could binarize ordinal features into High/Low groups and study their joint effects.
#
# **Tasks:**
# - Select k factors (e.g. k=2 or k=3) and define High/Low levels
# - Compute group means for all 2^k combinations
# - Analyze main effects and interaction effects
# - Visualize with interaction plots

# %% [markdown]
# #### 3.1 Select 3 significant factors from ANOVA (Part 2) and binarize into High/Low

# %%
# Selected features:
# Factor A: OverallQual — High (>= 7) vs Low (< 7)   [median split]
# Factor B: ExterQual   — High (Ex, Gd) vs Low (TA, Fa)
# Factor C: CentralAir  — Already binary (Y / N)

# Create a new df for factorial analysis
factorial_df = df.assign(
    A_OverallQual=(df["OverallQual"] >= 7).map({True: "High", False: "Low"}),
    B_ExterQual=df["ExterQual"].map({
        "Ex": "High",
        "Gd": "High",
        "TA": "Low",
        "Fa": "Low"
    }),
    C_CentralAir=df["CentralAir"].map({"Y": "High", "N": "Low"})
)

print("Factor A (OverallQual — High if >= 7):")
print(factorial_df["A_OverallQual"].value_counts())
print(f"\nFactor B (ExterQual — High if Ex/Gd):")
print(factorial_df["B_ExterQual"].value_counts())
print(f"\nFactor C (CentralAir — Y=High, N=Low):")
print(factorial_df["C_CentralAir"].value_counts())
# Out:
# Factor A (OverallQual — High if >= 7):
# A_OverallQual
# Low     912
# High    548
# Name: count, dtype: int64
#
# Factor B (ExterQual — High if Ex/Gd):
# B_ExterQual
# Low     920
# High    540
# Name: count, dtype: int64
#
# Factor C (CentralAir — Y=High, N=Low):
# C_CentralAir
# High    1365
# Low       95
# Name: count, dtype: int64

# %% [markdown]
# #### 3.2 Compute group means for all 2^k combinations

# %%
# --- Group means for all 2^3 combinations ---
factorial_groups = factorial_df.groupby(["A_OverallQual", "B_ExterQual", "C_CentralAir"]).agg(
    Mean_LogPrice=("LogSalePrice", "mean"),
    Count=("LogSalePrice", "count")
).reset_index()

print("2^3 Factorial Design — Group Means:")
print(factorial_groups.to_string(index=False))
# Out:
# 2^3 Factorial Design — Group Means:
# A_OverallQual B_ExterQual C_CentralAir  Mean_LogPrice  Count
#          High        High         High      12.425304    442
#          High        High          Low      12.360973      2
#          High         Low         High      12.168100    100
#          High         Low          Low      11.863456      4
#           Low        High         High      12.038994     94
#           Low        High          Low      11.633501      2
#           Low         Low         High      11.828445    729
#           Low         Low          Low      11.451549     87

# %%
# --- Visualization: group means bar chart ---
factorial_groups["Label"] = (
    factorial_groups["A_OverallQual"] + " / " +
    factorial_groups["B_ExterQual"] + " / " +
    factorial_groups["C_CentralAir"]
)

fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(factorial_groups["Label"], factorial_groups["Mean_LogPrice"],
              color=pink_light, edgecolor=pink_dark, linewidth=1.5)
ax.set_xlabel("OverallQual / ExterQual / CentralAir", fontweight='bold')
ax.set_ylabel("Mean LogPrice")
ax.set_title("2³ Factorial Design — Mean LogPrice per Group", fontweight='bold', color=pink_dark)
plt.xticks(rotation=45, ha='right')

for bar, count in zip(bars, factorial_groups["Count"]):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02,
            f'n={count}', ha='center', va='bottom', fontsize=9, color=pink_dark)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.3 Analyse main effects and interaction effects

# %%
model_factorial = smf.ols(
    "LogSalePrice ~ C(A_OverallQual) * C(B_ExterQual) * C(C_CentralAir)",
    data=factorial_df
).fit()

anova_table = sm.stats.anova_lm(model_factorial, typ=2)
anova_table["significant"] = anova_table["PR(>F)"] < 0.05
# Make the column names prettier
anova_table.index = anova_table.index.str.replace("C(", "", regex=False).str.replace(")", "", regex=False)

print(anova_table.index)

group_counts = factorial_df.groupby(["A_OverallQual","B_ExterQual","C_CentralAir"]).size()
print("Group counts:")
print(group_counts)

def log_effect_to_pct(x):
    return (np.exp(x) - 1) * 100

# =============================================================================
# Main Effects (log scale)
# =============================================================================
main_A = factorial_df.loc[factorial_df["A_OverallQual"]=="High", "LogSalePrice"].mean() - \
         factorial_df.loc[factorial_df["A_OverallQual"]=="Low",  "LogSalePrice"].mean()

main_B = factorial_df.loc[factorial_df["B_ExterQual"]=="High", "LogSalePrice"].mean() - \
         factorial_df.loc[factorial_df["B_ExterQual"]=="Low",  "LogSalePrice"].mean()

main_C = factorial_df.loc[factorial_df["C_CentralAir"]=="High", "LogSalePrice"].mean() - \
         factorial_df.loc[factorial_df["C_CentralAir"]=="Low",  "LogSalePrice"].mean()


# =============================================================================
# Interaction Effects (log scale)
# =============================================================================

# AB
interaction_AB = (
    (factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["B_ExterQual"]=="High"), "LogSalePrice"].mean() -
     factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["B_ExterQual"]=="High"), "LogSalePrice"].mean())
    -
    (factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["B_ExterQual"]=="Low"),  "LogSalePrice"].mean() -
     factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["B_ExterQual"]=="Low"),  "LogSalePrice"].mean())
) / 2

# AC
interaction_AC = (
    (factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean() -
     factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean())
    -
    (factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["C_CentralAir"]=="Low"),  "LogSalePrice"].mean() -
     factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["C_CentralAir"]=="Low"),  "LogSalePrice"].mean())
) / 2

# BC
interaction_BC = (
    (factorial_df.loc[(factorial_df["B_ExterQual"]=="High") & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean() -
     factorial_df.loc[(factorial_df["B_ExterQual"]=="Low")  & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean())
    -
    (factorial_df.loc[(factorial_df["B_ExterQual"]=="High") & (factorial_df["C_CentralAir"]=="Low"),  "LogSalePrice"].mean() -
     factorial_df.loc[(factorial_df["B_ExterQual"]=="Low")  & (factorial_df["C_CentralAir"]=="Low"),  "LogSalePrice"].mean())
) / 2

# ABC
mean_AH_BH_CH = factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["B_ExterQual"]=="High") & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean()
mean_AL_BH_CH = factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["B_ExterQual"]=="High") & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean()
mean_AH_BL_CH = factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["B_ExterQual"]=="Low")  & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean()
mean_AL_BL_CH = factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["B_ExterQual"]=="Low")  & (factorial_df["C_CentralAir"]=="High"), "LogSalePrice"].mean()

mean_AH_BH_CL = factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["B_ExterQual"]=="High") & (factorial_df["C_CentralAir"]=="Low"), "LogSalePrice"].mean()
mean_AL_BH_CL = factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["B_ExterQual"]=="High") & (factorial_df["C_CentralAir"]=="Low"), "LogSalePrice"].mean()
mean_AH_BL_CL = factorial_df.loc[(factorial_df["A_OverallQual"]=="High") & (factorial_df["B_ExterQual"]=="Low")  & (factorial_df["C_CentralAir"]=="Low"), "LogSalePrice"].mean()
mean_AL_BL_CL = factorial_df.loc[(factorial_df["A_OverallQual"]=="Low")  & (factorial_df["B_ExterQual"]=="Low")  & (factorial_df["C_CentralAir"]=="Low"), "LogSalePrice"].mean()

interaction_ABC = (
    mean_AH_BH_CH
    - mean_AL_BH_CH
    - mean_AH_BL_CH
    + mean_AL_BL_CH
    - mean_AH_BH_CL
    + mean_AL_BH_CL
    + mean_AH_BL_CL
    - mean_AL_BL_CL
) / 4

# =============================================================================
# Build final summary table
# =============================================================================

summary = pd.DataFrame({
    "Effect": [
        "A (OverallQual)",
        "B (ExterQual)",
        "C (CentralAir)",
        "A:B",
        "A:C",
        "B:C",
        "A:B:C"
    ],
    "Log_Effect": [
        main_A, main_B, main_C,
        interaction_AB, interaction_AC, interaction_BC, interaction_ABC
    ]
})

# Convert to %
summary["Percent_Change (%)"] = summary["Log_Effect"].apply(log_effect_to_pct)

# --- Map p-values from ANOVA ---
pval_map = {
    "A (OverallQual)": anova_table.loc["A_OverallQual", "PR(>F)"],
    "B (ExterQual)":   anova_table.loc["B_ExterQual", "PR(>F)"],
    "C (CentralAir)":  anova_table.loc["C_CentralAir", "PR(>F)"],
    "A:B":             anova_table.loc["A_OverallQual:B_ExterQual", "PR(>F)"],
    "A:C":             anova_table.loc["A_OverallQual:C_CentralAir", "PR(>F)"],
    "B:C":             anova_table.loc["B_ExterQual:C_CentralAir", "PR(>F)"],
    "A:B:C":           anova_table.loc["A_OverallQual:B_ExterQual:C_CentralAir", "PR(>F)"]
}

summary["p_value"] = summary["Effect"].map(pval_map)
summary["Significant"] = summary["p_value"] < 0.05

# --- Clean formatting ---
summary["Percent_Change (%)"] = summary["Percent_Change (%)"].round(2)
summary["p_value"] = summary["p_value"].round(4)

print("\nFinal 2^k Factorial Effects Summary:")
print(summary)

print(f"\nModel R² = {model_factorial.rsquared:.4f}")
print(f"Model Adj. R² = {model_factorial.rsquared_adj:.4f}")
# Out:
# Index(['A_OverallQual', 'B_ExterQual', 'C_CentralAir',
#        'A_OverallQual:B_ExterQual', 'A_OverallQual:C_CentralAir',
#        'B_ExterQual:C_CentralAir', 'A_OverallQual:B_ExterQual:C_CentralAir',
#        'Residual'],
#       dtype='object')
# Group counts:
# A_OverallQual  B_ExterQual  C_CentralAir
# High           High         High            442
#                             Low               2
#                Low          High            100
#                             Low               4
# Low            High         High             94
#                             Low               2
#                Low          High            729
#                             Low              87
# dtype: int64
# Final 2^k Factorial Effects Summary:
#             Effect  Log_Effect  Percent_Change (%)  p_value  Significant
# 0  A (OverallQual)    0.560268               75.11   0.0000         True
# 1    B (ExterQual)    0.525011               69.05   0.0000         True
# ...

# %%
# Bar chart of all effects
fig, ax = plt.subplots(figsize=(10, 5))
colors = [pink_light]*3 + [pink_main]*4
bars = ax.bar(summary["Effect"], summary["Log_Effect"],
              color=colors, edgecolor=pink_dark, linewidth=1.5)
ax.set_ylabel("Effect on LogSalePrice")
ax.set_title("Main Effects and Interaction Effects", fontweight='bold', color=pink_dark)
ax.axhline(y=0, color='gray', linestyle='-', linewidth=0.5)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.4 Visualise with interaction plots

# %%
# --- Interaction Plots ---
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

# --- Interaction Plot: OverallQual × ExterQual ---
sns.pointplot(
    data=factorial_df,
    x="A_OverallQual",
    y="LogSalePrice",
    hue="B_ExterQual",
    order=["Low", "High"],
    hue_order=["Low", "High"],
    palette=[pink_accent, pink_dark],
    ax=axes[0]
)

axes[0].set_xlabel("OverallQual Level", fontweight='bold')
axes[0].set_ylabel("Mean LogSalePrice")
axes[0].set_title("Interaction Plot: OverallQual × ExterQual", fontweight='bold', color=pink_dark)
axes[0].legend(title="ExterQual Level")
axes[0].grid(True, alpha=0.3)

# --- Interaction Plot: OverallQual × CentralAir ---
sns.pointplot(
    data=factorial_df,
    x="A_OverallQual",
    y="LogSalePrice",
    hue="C_CentralAir",
    order=["Low", "High"],
    hue_order=["Low", "High"],
    palette=[pink_accent, pink_dark],
    ax=axes[1]
)

axes[1].set_xlabel("OverallQual Level", fontweight='bold')
axes[1].set_title("Interaction Plot: OverallQual × CentralAir", fontweight='bold', color=pink_dark)
axes[1].legend(title="CentralAir Level")
axes[1].grid(True, alpha=0.3)

# --- Interaction Plot: ExterQual × CentralAir ---
sns.pointplot(
    data=factorial_df,
    x="B_ExterQual",
    y="LogSalePrice",
    hue="C_CentralAir",
    order=["Low", "High"],
    hue_order=["Low", "High"],
    palette=[pink_accent, pink_dark],
    ax=axes[2]
)

axes[2].set_xlabel("ExterQual Level", fontweight='bold')
axes[2].set_title("Interaction Plot: ExterQual × CentralAir", fontweight='bold', color=pink_dark)
axes[2].legend(title="CentralAir Level")
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Part 4: Parametric Regression
#
# Build a regression model using only the **significant ordinal features** identified by ANOVA (Part 2) plus the **2 numerical features**: `GrLivArea` and `TotalBsmtSF`.
#
# **Tasks:**
# - Encode ordinal features numerically (map quality levels to integers)
# - Fit a linear regression model (OLS)
# - Analyze the model: R², coefficient significance, residual plots
# - Optionally try regularized regression (Ridge, Lasso) and compare
# - Apply ANOVA on the regression model to assess factor contributions

# %% [markdown]
# #### Significant features:
#
# | # | Feature | Levels | Description |
# |---|---|---|---|
# | 1 | `OverallQual` | 1–10 | Overall material and finish quality |
# | 2 | `ExterQual` | Po, Fa, TA, Gd, Ex | Exterior material quality |
# | 3 | `BsmtQual` | None, Po, Fa, TA, Gd, Ex | Basement height quality |
# | 4 | `KitchenQual` | Po, Fa, TA, Gd, Ex | Kitchen quality |
# | 5 | `FireplaceQu` | None, Po, Fa, TA, Gd, Ex | Fireplace quality |
# | 6 | `CentralAir` | N, Y | Central air conditioning |
# | 7 | `LotShape` | IR3, IR2, IR1, Reg | General shape of property |
# | 8 | `GrLivArea` | | Above grade (ground) living area square feet  |
# | 9 | `TotalBsmtSF` |  | Total square feet of basement area |

# %%
target = "LogSalePrice"

# Split the data for predictions
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# #### 4.1 Encode ordinal features numerically (map quality levels to integers)

# %%
# Encode and prepare ordinal features for regression
feat = ["OverallQual", "ExterQual", "BsmtQual", "KitchenQual", "FireplaceQu", "CentralAir", "LotShape", "GrLivArea", "TotalBsmtSF"]

def preprocess(data):
  encoded_df = data[feat].copy()

  qual_encoding = {
    "Ex": 5,
    "Gd": 4,
    "TA": 3,
    "Fa": 2,
    "Po": 1,
    "None": 0
  }

  # Apply mappings to quality features
  for col in ["ExterQual", "BsmtQual", "KitchenQual", "FireplaceQu"]:
    encoded_df[col] = encoded_df[col].map(qual_encoding)

  # Encode CentralAir: No -> 0, Yes -> 1
  encoded_df["CentralAir"] = encoded_df["CentralAir"].map({ "N": 0, "Y": 1 })

  # Tukey showed that Reg differs from IR1 and IR2, but IR1 ≈ IR2 ≈ IR3 and Reg ≈ IR3.
  # So main signal is regular vs irregular.
  # Let's use one-hot encoding, with Reg as baseline.
  encoded_df["LotShape"] = encoded_df["LotShape"].astype("category")
  encoded_df["LotShape"] = encoded_df["LotShape"].cat.reorder_categories(
      ["Reg", "IR1", "IR2", "IR3"], ordered=False
  )
  lotshape_dummies = pd.get_dummies(encoded_df["LotShape"], prefix="LotShape", drop_first=True).astype(int)
  encoded_df = encoded_df.drop(columns=["LotShape"])
  encoded_df = pd.concat([encoded_df, lotshape_dummies], axis=1)

  # Handle missing values
  encoded_df = encoded_df.fillna(0)

  return encoded_df

# Apply preprocessing to training data
X_train = preprocess(train_df)

# %% [markdown]
# #### 4.2 Fit a linear regression model (OLS)

# %%
# Prepare train target
y_train = train_df[target]

# Add intercept term and fit model
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           LogSalePrice   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     451.2
# Date:                Tue, 26 May 2026   Prob (F-statistic):               0.00
# Time:                        19:03:29   Log-Likelihood:                 414.35
# No. Observations:                1168   AIC:                            -804.7
# Df Residuals:                    1156   BIC:                            -743.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.2740      0.035    296.320      0.000      10.206      10.342
# ...

# %% [markdown]
# #### 4.3 Analyze the model: R², coefficient significance, residual plots

# %%
residuals = model.resid
fitted = model.fittedvalues

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# --- Residuals vs Fitted ---
axes[0].scatter(fitted, residuals, color=pink_main)
axes[0].axhline(0, color=pink_dark)
axes[0].set_title("Residuals vs Fitted", fontweight="bold", color=pink_dark)
axes[0].set_xlabel("Fitted values")
axes[0].set_ylabel("Residuals")

# --- Histogram of residuals ---
axes[1].hist(residuals, bins=30, color=pink_main)
axes[1].set_title("Residual distribution", fontweight="bold", color=pink_dark)
axes[1].set_xlabel("Residuals")
axes[1].set_ylabel("Frequency")

# --- QQ plot ---
stats.probplot(residuals, dist="norm", plot=axes[2])
axes[2].set_title('Q-Q plot', fontweight='bold', color=pink_dark)
axes[2].get_lines()[0].set_markerfacecolor(pink_light)
axes[2].get_lines()[0].set_markeredgecolor(pink_main)
axes[2].get_lines()[0].set_markersize(3)
axes[2].get_lines()[1].set_color(pink_dark)

plt.tight_layout()
plt.show()

# %%
bp_test = sms.het_breuschpagan(model.resid, model.model.exog)

print("Lagrange multiplier p-value:", bp_test[1])
# Out:
# Lagrange multiplier p-value: 1.0384630753242722e-53

# %% [markdown]
# BP test indicates heteroscedasticity. We'll handle this by adjusting the model using robust standard errors.

# %%
model_robust = model.get_robustcov_results(cov_type="HC3")
print(model_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           LogSalePrice   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     338.7
# Date:                Tue, 26 May 2026   Prob (F-statistic):               0.00
# Time:                        19:03:29   Log-Likelihood:                 414.35
# No. Observations:                1168   AIC:                            -804.7
# Df Residuals:                    1156   BIC:                            -743.9
# Df Model:                          11
# Covariance Type:                  HC3
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.2740      0.050    207.312      0.000      10.177      10.371
# ...

# %% [markdown]
# After correction for heteroscedasticity using HC3 robust standard error, some weaker signals drop out (basement area, lot shape IR3). Overall quality, kitchen quality, air conditioning and living area size remain highly significant as strong predictors of house price.

# %%
# Prepare test data for evaluation (we'll use this to compare to Ridge and Lasso)
X_test = preprocess(test_df)
y_test = test_df[target]

# Align columns
cols = X_train.copy().columns.drop("const")
X_test = X_test.reindex(columns=cols, fill_value=0)

# Include constant as before for X_train
X_test = sm.add_constant(X_test)
y_pred_test = model.predict(X_test)

# Calculate training RMSE too for comparison
y_pred_train = model.predict(X_train)
rmse_train = np.sqrt(np.mean((y_train - y_pred_train)**2))

print("Train R²:", r2_score(y_train, y_pred_train))
print("Train RMSE:", np.sqrt(mean_squared_error(y_train, y_pred_train)))
print()
print("Test R²:", r2_score(y_test, y_pred_test))
print("Test RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_test)))
# Out:
# Train R²: 0.8110768870538271
# Train RMSE: 0.169705331256849
#
# Test R²: 0.8405325799524606
# Test RMSE: 0.17250615323174306

# %% [markdown]
# #### 4.4 Regularized regression (Ridge, Lasso) and comparison
#
# ##### 4.4.1 Apply scaling before doing regularisation

# %%
# Rebuild X and y without statsmodel constant
X_train = preprocess(train_df)
y_train = train_df[target]
X_test = preprocess(test_df)
y_test = test_df[target]

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# ##### 4.4.2 Ridge and Lasso on scaled data

# %%
# Try different regularization strengths
alphas = [0.001, 0.01, 0.1, 1, 10]

results = []

for alpha in alphas:
    # Ridge regression
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train_scaled, y_train)
    ridge_pred = ridge.predict(X_test_scaled)

    results.append({
        "Model": "Ridge",
        "Alpha": alpha,
        "Test R²": r2_score(y_test, ridge_pred),
        "Test RMSE": np.sqrt(mean_squared_error(y_test, ridge_pred))
    })

    # Lasso regression
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(X_train_scaled, y_train)
    lasso_pred = lasso.predict(X_test_scaled)

    results.append({
        "Model": "Lasso",
        "Alpha": alpha,
        "Test R²": r2_score(y_test, lasso_pred),
        "Test RMSE": np.sqrt(mean_squared_error(y_test, lasso_pred))
    })

regularization_results = pd.DataFrame(results)
# Sort to see the best model
regularization_results.sort_values("Test RMSE")
# Out:
#    Model   Alpha   Test R²  Test RMSE
# 0  Ridge   0.001  0.840533   0.172506
# 2  Ridge   0.010  0.840532   0.172506
# 4  Ridge   0.100  0.840529   0.172508
# 6  Ridge   1.000  0.840499   0.172524
# 8  Ridge  10.000  0.840189   0.172692
# 1  Lasso   0.001  0.840164   0.172706
# 3  Lasso   0.010  0.834723   0.175620
# 5  Lasso   0.100  0.682636   0.243359
# 7  Lasso   1.000 -0.005837   0.433244
# 9  Lasso  10.000 -0.005837   0.433244

# %% [markdown]
# ##### 4.4.3 See which variables Lasso keeps

# %%
best_alpha = regularization_results[regularization_results["Model"] == "Lasso"
                                    ].sort_values("Test RMSE").iloc[0]["Alpha"]


best_lasso = Lasso(alpha=best_alpha, max_iter=10000)
best_lasso.fit(X_train_scaled, y_train)

lasso_coefficients = pd.DataFrame({"Feature": X_train.columns, "Coefficient": best_lasso.coef_})

lasso_coefficients["Selected"] = lasso_coefficients["Coefficient"] != 0

lasso_coefficients.sort_values(
    by="Coefficient",
    key=abs,
    ascending=False
)
# Out:
#          Feature  Coefficient  Selected
# 6      GrLivArea     0.115516      True
# 0    OverallQual     0.115246      True
# 5     CentralAir     0.049525      True
# 3    KitchenQual     0.047320      True
# 2       BsmtQual     0.042044      True
# 7    TotalBsmtSF     0.038673      True
# 4    FireplaceQu     0.035653      True
# 1      ExterQual     0.024977      True
# 8   LotShape_IR1     0.024558      True
# 9   LotShape_IR2     0.021821      True
# 10  LotShape_IR3    -0.011013      True

# %% [markdown]
# #### 4.5 ANOVA on the regression model to assess factor contributions

# %%
# Put X_train and y_train back into one dataframe
anova_df = X_train.copy()
anova_df["LogSalePrice"] = y_train

# Build formula from all predictors used in X_train
predictors = X_train.columns.tolist()
formula = "LogSalePrice ~ " + " + ".join(predictors)

# Fit OLS model
anova_model = smf.ols(formula=formula, data=anova_df).fit()

# ANOVA table
anova_results = anova_lm(anova_model, typ=2)

# Add significance column
anova_results["significant_0.05"] = anova_results["PR(>F)"] < 0.05
anova_results.sort_values("PR(>F)")
# Out:
#                  sum_sq      df           F        PR(>F)  significant_0.05
# GrLivArea      8.922880     1.0  306.640178  4.450128e-61              True
# OverallQual    4.571673     1.0  157.108321  6.928020e-34              True
# CentralAir     2.532132     1.0   87.018263  5.303728e-20              True
# KitchenQual    1.102121     1.0   37.875055  1.038221e-09              True
# FireplaceQu    1.054146     1.0   36.226361  2.355501e-09              True
# TotalBsmtSF    1.043284     1.0   35.853096  2.836332e-09              True
# BsmtQual       1.023338     1.0   35.167645  3.990466e-09              True
# LotShape_IR1   0.692688     1.0   23.804645  1.215393e-06              True
# LotShape_IR2   0.582519     1.0   20.018635  8.425903e-06              True
# ExterQual      0.283090     1.0    9.728558  1.859136e-03              True
# LotShape_IR3   0.164630     1.0    5.657622  1.754137e-02              True
# ...

# %% [markdown]
# ---
# ## Part 5: Non-Parametric Model (Neural Network)
#
# Build a neural network regression model using **all** available features to predict SalePrice. This is also the model that produces your `submission.csv` for Kaggle scoring.
#
# **Tasks:**
# - Preprocess all features: handle missing values, encode categoricals, scale numerics
# - Build and train a neural network (e.g. `sklearn.neural_network.MLPRegressor` or PyTorch)
# - Evaluate on training data (RMSE, R²) and analyze residuals
# - Generate predictions for the test set and save as `submission.csv`
#
# **Important:** The Kaggle RMSE score is evaluated on the predictions from this model.

# %%
df_train = train.copy()
df_train["LogSalePrice"] = np.log1p(df_train["SalePrice"])

df_test = test.copy()

# Clean both train and test datasets
df_train = clean_data(df_train)
df_test = clean_data(df_test)

print("Kaggle train data (with LogSalePrice)")
display(df_train)
print("="*250)
print("Kaggle test data")
display(df_test)
# Out:
# Kaggle train data (with LogSalePrice)
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None      Reg
# 1        2          20       RL         80.0     9600   Pave  None      Reg
# 2        3          60       RL         68.0    11250   Pave  None      IR1
# 3        4          70       RL         60.0     9550   Pave  None      IR1
# 4        5          60       RL         84.0    14260   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
# ...

# %%
# Train dataset
X = df_train.drop(columns=["SalePrice", "LogSalePrice", "Id"], errors="ignore")
target = "LogSalePrice"
y = df_train[target] # target = LogSalePrice

# Test dataset
X_test = df_test.drop(columns=["Id"], errors="ignore")

# %% [markdown]
# #### 1) Preprocess all features: handle missing values, encode categoricals, scale numerics
#
# - fill missing values
# - Scale numeric columns
# - Encode categorical columns

# %%
# Identify numeric and categorical columns
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object", "category"]).columns

# Numeric preprocessing
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# Categorical preprocessing
categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

# Combine preprocessing
preprocessor_nn = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

# %% [markdown]
# #### 2) Build and train a neural network using `sklearn.neural_network.MLPRegressor`
#
# ##### Find optimal hyperparameters
#
# Looking into different activation functions:
# - `logistic`, `relu` and `tanh`
#
# Looking into different values for:
# - `hidden layer` architecture
# - ` regularization strengths (alpha)`
# - `learning rate`
# - `batch size`

# %%
# Neural Network pipeline with preprocessing and MLP model
mlp_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor_nn),
    ("mlp", MLPRegressor(
        solver="adam",
        max_iter=3000,
        early_stopping=True,
        n_iter_no_change=30,
        random_state=42
    ))
])

# Hyperparameter combinations to evaluate
param_grid = {
    "mlp__hidden_layer_sizes": [
        (16, 8),
        (16, 8, 4),
        (24, 14, 7),
        (32, 16, 8),
        (64, 32, 16)
    ],
    "mlp__activation": ["logistic", "relu", "tanh"],
    "mlp__alpha": [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05],
    "mlp__learning_rate_init": [0.0001, 0.0005, 0.001, 0.002, 0.005, 0.01],
    "mlp__batch_size": [8, 16, 32]
}

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Performs grid search with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=mlp_pipeline,
    param_grid=param_grid,
    cv=kf,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    verbose=1
)

# Train the model and evaluate all parameter combinations
grid_search.fit(X, y)

# Store and organize cross-validation results
results_df = pd.DataFrame(grid_search.cv_results_)
results_df["rmse_mean"] = -results_df["mean_test_score"]
results_df["rmse_std"] = results_df["std_test_score"]
results_df["rmse_variance"] = results_df["rmse_std"] ** 2
results_df = results_df.sort_values("rmse_mean")


print("\nBest parameters:")
for key, value in grid_search.best_params_.items():
    print(f"{key}: {value}")

print(f"\nBest CV RMSE: {-grid_search.best_score_:.5f}")
# Out:
# Fitting 5 folds for each of 1620 candidates, totalling 8100 fits
#
# Best parameters:
# mlp__activation: logistic
# mlp__alpha: 0.0005
# mlp__batch_size: 16
# mlp__hidden_layer_sizes: (32, 16, 8)
# mlp__learning_rate_init: 0.0001
#
# Best CV RMSE: 0.12314

# %%
display(results_df[[
    "rmse_mean",
    "rmse_std",
    "rmse_variance",
    "param_mlp__hidden_layer_sizes",
    "param_mlp__alpha",
    "param_mlp__learning_rate_init",
    "param_mlp__batch_size"]].head(10))
# Out:
#      rmse_mean  rmse_std  rmse_variance param_mlp__hidden_layer_sizes  \
# 138   0.123145  0.011613       0.000135                   (32, 16, 8)
# 168   0.123359  0.010129       0.000103                   (32, 16, 8)
# 228   0.123964  0.011635       0.000135                   (32, 16, 8)
# 18    0.124041  0.013015       0.000169                   (32, 16, 8)
# 186   0.124080  0.013542       0.000183                    (16, 8, 4)
# 258   0.124241  0.010825       0.000117                   (32, 16, 8)
# 12    0.124264  0.013870       0.000192                   (24, 14, 7)
# 252   0.124536  0.013011       0.000169                   (24, 14, 7)
# 336   0.124712  0.013518       0.000183                    (16, 8, 4)
# 132   0.124803  0.014366       0.000206                   (24, 14, 7)
#
#      param_mlp__alpha  param_mlp__learning_rate_init  param_mlp__batch_size
# 138            0.0005                         0.0001                     16
# ...

# %%
# Visualize the relationship between architecture, regularization, and model performance
results_df["architecture"] = results_df["param_mlp__hidden_layer_sizes"].astype(str)
plot_df = (results_df.groupby(["architecture", "param_mlp__alpha"], as_index=False)["rmse_mean"].min())

plt.figure(figsize=(11, 6))

sns.lineplot(data=plot_df, x="param_mlp__alpha", y="rmse_mean", hue="architecture", marker="o")

plt.xscale("log")
plt.title("Effect of Architecture and Regularization on RMSE")
plt.xlabel("Regularization strength alpha")
plt.ylabel("Best mean CV RMSE")
plt.legend(title="Architecture")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Visualize the relationship between architecture, batch size, and model performance
results_df["architecture"] = results_df["param_mlp__hidden_layer_sizes"].astype(str)

plot_df = (results_df.groupby(["architecture", "param_mlp__batch_size"], as_index=False)["rmse_mean"].min())

plt.figure(figsize=(11, 6))

sns.lineplot(
    data=plot_df,
    x="param_mlp__batch_size",
    y="rmse_mean",
    hue="architecture",
    marker="o"
)

plt.xticks([8, 16, 32])

plt.title("Effect of Architecture and Batch Size on RMSE")
plt.xlabel("Batch size")
plt.ylabel("Best mean CV RMSE")
plt.legend(title="Architecture")
plt.grid(True, alpha=0.3)

plt.show()

# %%
# Visualize the relationship between learning rate, regularization, and model performance
plot_df = (results_df.groupby(["param_mlp__alpha", "param_mlp__learning_rate_init"],as_index=False)["rmse_mean"].min())

plt.figure(figsize=(11,6))

sns.lineplot(
    data=plot_df,
    x="param_mlp__learning_rate_init",
    y="rmse_mean",
    hue="param_mlp__alpha",
    marker="o",
    palette=sns.color_palette("seismic", n_colors=6)
)

plt.xscale("log")

plt.title("Effect of Learning Rate and Alpha on RMSE")
plt.xlabel("Learning rate")
plt.ylabel("Best mean CV RMSE")
plt.legend(title="Alpha")
plt.grid(True, alpha=0.3)

plt.show()

# %%
# Evaluate the selected model using five-fold cross-validation
model = Pipeline(steps=[
    ("preprocessor", preprocessor_nn),
    ("mlp", MLPRegressor(
        hidden_layer_sizes=(32, 16, 8),
        activation="logistic",
        solver="adam",
        alpha=0.0005,
        learning_rate_init=0.0001,
        batch_size=16,
        max_iter=3000,
        early_stopping=True,
        n_iter_no_change=30,
        random_state=42,
        tol=1e-4
    ))
])

scores = cross_val_score(model, X, y, cv=KFold(n_splits=5, shuffle=True, random_state=42), scoring="neg_root_mean_squared_error")

print(-scores.mean(), scores.std())
# Out:
# 0.12314474608417476 0.0116131555848365

# %% [markdown]
# #### 3) Evaluate on training data (RMSE, R²) and analyze residuals

# %%
# Use the best model found by GridSearchCV
best_model = grid_search.best_estimator_

# Train on entire training dataset
best_model.fit(X, y)

# Predictions on training data
y_pred = best_model.predict(X)

# Metrics (RMSE and R²)
rmse = np.sqrt(mean_squared_error(y, y_pred))
r2 = r2_score(y, y_pred)

print("="*50)
print("Training R²:", round(r2,4))
print("Training RMSE:", round(rmse,4))
print("="*50)
# Out:
# ...
# Training R²: 0.9384
# Training RMSE: 0.0991
# ...

# %%
# Actual vs predicted values comparison
plt.figure(figsize=(8,6))

plt.scatter(y, y_pred, alpha=0.4, color=pink_light)

plt.plot([y.min(), y.max()], [y.min(), y.max()], "r--", color=pink_dark)

plt.xlabel("Actual LogSalePrice")
plt.ylabel("Predicted LogSalePrice")
plt.title("Predicted vs Actual Values")

plt.show()
# Out:
# /var/folders/27/rq2dhm5d6wlg0zggr3qmyz3c0000gn/T/ipykernel_16249/774476282.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot([y.min(), y.max()], [y.min(), y.max()], "r--", color=pink_dark)

# %%
# Residuals visualization 
plt.figure(figsize=(8,6))

# Residuals
residuals = y - y_pred
print("Mean residual:", (residuals).mean())

plt.scatter(y_pred, residuals, alpha=0.4, color=pink_light)

plt.axhline(y=0, linestyle="--", color=pink_dark)
plt.xlabel("Predicted LogSalePrice")
plt.ylabel("Residuals")
plt.title("Residual Plot - Neural Network")
plt.show()
# Out:
# Mean residual: 0.0021099943495806544

# %%
# Inspect the outliers
outliers = pd.DataFrame({"actual": y, "predicted": y_pred, "residual": residuals})

outliers["abs_residual"] = abs(outliers["residual"])

outliers.sort_values("abs_residual", ascending=False).head(10)
# Out:
#          actual  predicted  residual  abs_residual
# 1298  11.982935  13.011767 -1.028831      1.028831
# 523   12.126764  13.007894 -0.881130      0.881130
# 632   11.320566  12.077883 -0.757317      0.757317
# 1324  11.898195  12.512266 -0.614071      0.614071
# 691   13.534474  12.995103  0.539371      0.539371
# 1182  13.521141  12.997017  0.524124      0.524124
# 462   11.041064  11.553713 -0.512649      0.512649
# 30    10.596660  11.025741 -0.429081      0.429081
# 588   11.870607  12.283903 -0.413296      0.413296
# 968   10.542733  10.949781 -0.407048      0.407048

# %%
# Residual distribution visualization 
plt.figure(figsize=(8,6))

plt.hist(residuals, bins=40, edgecolor="black", color=pink_light)

plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution - Neural Network")
plt.show()

# %%
# QQ Plot 
plt.figure(figsize=(8,5))

stats.probplot(residuals, dist="norm", plot=plt)

ax = plt.gca()
ax.get_lines()[0].set_markerfacecolor("lightpink")   
ax.get_lines()[0].set_markeredgecolor("lightpink")
ax.get_lines()[1].set_color("deeppink")        

plt.title("Residual QQ Plot")
plt.show()

# %%
# NN Learning curve
plt.figure(figsize=(8,5))

loss_values = best_model.named_steps["mlp"].loss_curve_
plt.plot(loss_values, color=pink_dark)

plt.grid(True, alpha=0.3, linestyle="--", color=pink_light)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Neural Network Learning Curve")
plt.show()

# %% [markdown]
# #### 4) Generate predictions for the test set and save as `submission.csv`

# %%
# Final Neural Network that uses the selected hyperparameters
final_model = Pipeline(steps=[
    ("preprocessor", preprocessor_nn),
    ("mlp", MLPRegressor(
        hidden_layer_sizes=(32, 16, 8),
        activation="logistic",
        solver="adam",
        alpha=0.0005,
        learning_rate_init=0.0001,
        batch_size=16,
        max_iter=3000,
        early_stopping=True,
        n_iter_no_change=30,
        random_state=42,
        tol=1e-4
    ))
])

# %%
# Train the final model and generate predictions for the test dataset
final_model.fit(X, y)

y_test_pred_log = final_model.predict(X_test)
y_test_pred_price = np.expm1(y_test_pred_log)

# Create and save the Kaggle submission file
submission = pd.DataFrame({
    "Id" : df_test["Id"],
    "SalePrice" : y_test_pred_price
})

submission.to_csv("submission.csv", index=False)
submission.head(10)
# Out:
#      Id      SalePrice
# 0  1461  125983.063331
# 1  1462  166788.251442
# 2  1463  180187.941321
# 3  1464  195043.852069
# 4  1465  185741.935431
# 5  1466  169666.277423
# 6  1467  172011.883963
# 7  1468  161966.410635
# 8  1469  184292.080683
# 9  1470  127957.108212

# %%
# Visualize the distribution of predicted values in both scales
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Means
mean_log = np.mean(y_test_pred_log)
print(f"Mean predicetd LogSalePrice: {mean_log:.4f}")
mean_price = np.mean(y_test_pred_price)
print(f"Mean predicetd SalePrice: {mean_price:.0f}$")

# Log-transformed predictions
axes[0].hist(y_test_pred_log, bins=40, color=pink_light, edgecolor="black")

axes[0].axvline(mean_log, color=pink_dark, linestyle="--", linewidth=2, label=f"Mean = {mean_log:.3f}")

axes[0].set_title("Distribution of Predicted LogSalePrice")
axes[0].set_xlabel("LogSalePrice")
axes[0].set_ylabel("Frequency")

axes[0].legend()


# Original price predictions
axes[1].hist(y_test_pred_price, bins=40, color=pink_light, edgecolor="black")

axes[1].axvline(mean_price, color=pink_dark, linestyle="--", linewidth=2, label=f"Mean = {mean_price:.0f}")

axes[1].set_title("Distribution of Predicted SalePrice")
axes[1].set_xlabel("SalePrice")
axes[1].set_ylabel("Frequency")

axes[1].legend()


plt.tight_layout()
plt.show()
# Out:
# Mean predicetd LogSalePrice: 12.0071
# Mean predicetd SalePrice: 177491$
